# %%
'''
Data is based on the transcation history on 2026-01-01
'''

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

inputs = r"C:\Users\Shenghui\Documents\GitHub\MSc_DV_CC\Task3\blockchair_bitcoin_inputs_20260101.tsv"
outputs = r"C:\Users\Shenghui\Documents\GitHub\MSc_DV_CC\Task3\blockchair_bitcoin_outputs_20260101.tsv"

# %%
idf = pd.read_csv(inputs,sep="\t")
odf = pd.read_csv(outputs,sep="\t")

# %%
idf.head()
# Out:
#    block_id                                   transaction_hash  index  \
# 0    925940  1c8fddb2190947d73d8abf570b6acbc0f71c14ddfa2726...      0
# 1    925940  edb174b0c2b5d50cd4204991fe98eae0653eec81c24ccc...      0
# 2    925945  7d60e781c169bd564a848554ff62b6145fe4b81ae5783b...      0
# 3    925943  125798cb5ea3af6e342561c2a670f3d70159b26b063549...      0
# 4    925945  67cbe3c8c0a185fca6626cc1980a32912f7e58e8c03890...      0
#
#                   time   value  value_usd                           recipient  \
# 0  2025-12-01 00:04:53  226510   204.4117  1FGiZB7K757EUixGcyeyME6Jp8qQZEiUUk
# 1  2025-12-01 00:04:53  161927   146.1294  1FGiZB7K757EUixGcyeyME6Jp8qQZEiUUk
# 2  2025-12-01 01:22:43  231716   209.1098  1GzgDCeDyeb4sKQZJZu5rUjAcgRvBBJiY7
# 3  2025-12-01 00:42:53  152700   137.8026  1GzgDCeDyeb4sKQZJZu5rUjAcgRvBBJiY7
# 4  2025-12-01 01:22:43  231716   209.1098  1GzgDCeDyeb4sKQZJZu5rUjAcgRvBBJiY7
#
#          type                                         script_hex  \
# ...

# %%
idf.dtypes
# Out:
# block_id                       int64
# transaction_hash              object
# index                          int64
# time                          object
# value                          int64
# value_usd                    float64
# recipient                     object
# type                          object
# script_hex                    object
# is_from_coinbase               int64
# is_spendable                   int64
# spending_block_id              int64
# spending_transaction_hash     object
# spending_index                 int64
# spending_time                 object
# spending_value_usd           float64
# spending_sequence              int64
# spending_signature_hex        object
# spending_witness              object
# lifespan                       int64
# cdd                          float64
# dtype: object

# %%
odf.head()
# Out:
#    block_id                                   transaction_hash  index  \
# 0    930341  1095a28fd257ecf76947002121e233d780a33d73bd9fdb...      0
# 1    930341  1095a28fd257ecf76947002121e233d780a33d73bd9fdb...      1
# 2    930341  1095a28fd257ecf76947002121e233d780a33d73bd9fdb...      1
# 3    930341  1095a28fd257ecf76947002121e233d780a33d73bd9fdb...      1
# 4    930341  1095a28fd257ecf76947002121e233d780a33d73bd9fdb...      2
#
#                   time      value    value_usd  \
# 0  2026-01-01 00:06:10        546       0.4778
# 1  2026-01-01 00:06:10  314440653  275185.8750
# 2  2026-01-01 00:06:10  314440653  275185.8750
# 3  2026-01-01 00:06:10  314440653  275185.8750
# 4  2026-01-01 00:06:10          0       0.0000
#
#                             recipient        type  \
# 0  3Eif1JfqeMERRsQHtvGEacNN9hhuvnsfe9  scripthash
# 1  3Awm3FNpmwrbvAFVThRUFqgpbVuqWisni9  scripthash
# 2  3Awm3FNpmwrbvAFVThRUFqgpbVuqWisni9  scripthash
# 3  3Awm3FNpmwrbvAFVThRUFqgpbVuqWisni9  scripthash
# ...

# %%
odf.dtypes
# Out:
# block_id              int64
# transaction_hash     object
# index                 int64
# time                 object
# value                 int64
# value_usd           float64
# recipient            object
# type                 object
# script_hex           object
# is_from_coinbase      int64
# is_spendable          int64
# dtype: object

# %%
itime = idf["time"].value_counts()
print(itime)
otime = odf["time"].value_counts()
print(otime)
# Out:
# time
# 2026-01-01 00:37:58    8238
# 2026-01-01 02:53:17    7275
# 2026-01-01 14:00:04    6383
# 2026-01-01 03:13:53    6378
# 2026-01-01 01:47:14    6281
#                        ...
# 2022-11-22 17:06:47       1
# 2021-11-08 12:36:17       1
# 2022-03-20 12:56:59       1
# 2022-02-23 12:59:03       1
# 2022-02-04 13:24:36       1
# Name: count, Length: 42043, dtype: int64
# time
# 2026-01-01 20:11:33    16898
# 2026-01-01 03:13:53    16617
# 2026-01-01 00:37:58    16017
# 2026-01-01 09:44:34    15960
# 2026-01-01 10:04:03    15649
#                        ...
# 2026-01-01 04:13:10      702
# 2026-01-01 08:30:49      629
# 2026-01-01 11:38:26      492
# 2026-01-01 06:28:19      381
# 2026-01-01 23:32:43      315
# Name: count, Length: 151, dtype: int64

# %%
icounts = idf["recipient"].value_counts()
print(icounts)

ocounts = odf["recipient"].value_counts()
print(ocounts)
# Out:
# recipient
# bc1pvad59hdlahwa66yv6qdn8vgd5d7p4usx88x54u0gqzz3y85yrcpq0fcfv2    46136
# bc1pv6eqwxkxxda5nj49cry8z7lqnc2ft5hxz3jf0mx3v67e4c0krc8qzgjaa7    33957
# bc1pwucn9l7vhfcp4k93xs5nu4r7tmd7qqmcnz5ekl877fp0l6cky7rqjgz4ck    29036
# bc1pcecas3up00urhzjpqf5yagndfs7mhfmzuyl4yk68neqzgnsxjh9s7vk4ww    21451
# bc1pxpyjtcmr8kuct4rtpfjjm4shc05zm08r0mzz5986tn5q5sulm58qq3zlam    19585
#                                                                   ...
# 13FnJDGha3aPD8e86T4CDhCyNf6KJ8jxuC                                    1
# bc1qvf6jdkzcp27gytq57rxkqvhqanr8zgfmusn445                            1
# bc1qr6l0wyx05qcm44gg9s9n66pz2ac76ftrnkk65q                            1
# bc1qmkwdj2wcw6dkwa6e6dj957lpfze4f23lvck282                            1
# bc1q74ex69ygl07fa7t9zm5xe09ym8e7uym5wy7gdmspqsr7fgryp7gsufpqhl        1
# Name: count, Length: 400426, dtype: int64
# recipient
# d-39fb509d8eb10633e0e951c77bd3a7cb                                140748
# ...

# %%
df = pd.merge(
    odf,
    idf,
    on=['transaction_hash','index'],
    how='left',
    suffixes=('_created','_spent')
)

# %%
df.head()
# Out:
#    block_id_created                                   transaction_hash  index  \
# 0            930341  1095a28fd257ecf76947002121e233d780a33d73bd9fdb...      0
# 1            930341  1095a28fd257ecf76947002121e233d780a33d73bd9fdb...      1
# 2            930341  1095a28fd257ecf76947002121e233d780a33d73bd9fdb...      1
# 3            930341  1095a28fd257ecf76947002121e233d780a33d73bd9fdb...      1
# 4            930341  1095a28fd257ecf76947002121e233d780a33d73bd9fdb...      2
#
#           time_created  value_created  value_usd_created  \
# 0  2026-01-01 00:06:10            546             0.4778
# 1  2026-01-01 00:06:10      314440653        275185.8750
# 2  2026-01-01 00:06:10      314440653        275185.8750
# 3  2026-01-01 00:06:10      314440653        275185.8750
# 4  2026-01-01 00:06:10              0             0.0000
#
#                     recipient_created type_created  \
# 0  3Eif1JfqeMERRsQHtvGEacNN9hhuvnsfe9   scripthash
# ...

# %%
len(df)
# Out:
# 1524592

# %%
df = df.dropna(subset=['spending_transaction_hash'])

# %%
len(df)
# Out:
# 766760

# %%
df.columns
# Out:
# Index(['block_id_created', 'transaction_hash', 'index', 'time_created',
#        'value_created', 'value_usd_created', 'recipient_created',
#        'type_created', 'script_hex_created', 'is_from_coinbase_created',
#        'is_spendable_created', 'block_id_spent', 'time_spent', 'value_spent',
#        'value_usd_spent', 'recipient_spent', 'type_spent', 'script_hex_spent',
#        'is_from_coinbase_spent', 'is_spendable_spent', 'spending_block_id',
#        'spending_transaction_hash', 'spending_index', 'spending_time',
#        'spending_value_usd', 'spending_sequence', 'spending_signature_hex',
#        'spending_witness', 'lifespan', 'cdd'],
#       dtype='object')

# %%
df['spending_time'] = pd.to_datetime(df['spending_time'])
start_time = pd.to_datetime('2026-01-01 00:00:00')
end_time   = start_time + pd.Timedelta(minutes=10)
df_window = df[(df['spending_time'] >= start_time) & (df['spending_time'] < end_time)]

# %%
class BitcoinTran:
    def __init__(self,deltaMins,st):

# %%
len(df_window)
# Out:
# 1906

# %%
G = nx.from_pandas_edgelist(
    df_window,
    source='transaction_hash',
    target='spending_transaction_hash',
    edge_attr='value_spent',
    create_using=nx.DiGraph()
)

# 3. Save as a .gexf file
print("Exporting graph... this might take a minute.")
nx.write_gexf(G, "bitcoin_network_10mins.gexf")
print("Done! Open 'bitcoin_network.gexf' in Gephi.")
# Out:
# Exporting graph... this might take a minute.
# Done! Open 'bitcoin_network.gexf' in Gephi.

# %%
total = len(bit_df)
Max_amount = bit_df["Amount"].max()
Min_amount = bit_df["Amount"].min()
Max_T = bit_df["Timestamp"].max()
Min_T = bit_df["Timestamp"].min()
print(f"{Max_amount=:}")
print(f"{Min_amount=:}")
print(f"{Max_T=:}")
print(f"{Min_T=:}")
print("Total transcations:", total)
# Out:
# Max_amount=14.99994312
# Min_amount=0.01010116
# Max_T=2025-05-11T15:10:41.695411Z
# Min_T=2025-03-03T04:47:40.702223Z
# Total transcations: 24988

# %%
counts = bit_df["Receiver_Address"].value_counts()
duplicates = counts[counts > 1].index.tolist()
print(duplicates)

counts = bit_df["Sender_Address"].value_counts()
duplicates = counts[counts > 1].index.tolist()
print(duplicates)

#c = pd.Series(["a","a"])
counts = bit_df["Block_ID"].value_counts()
duplicates = counts[counts > 1].index.tolist()
print(duplicates)
# Out:
# []
# []
# []

# %%
gradient = np.linspace(math.floor(Min_amount), math.ceil(Max_amount)).reshape(1, -1)

plt.figure(figsize=(8, 1.5))
plt.imshow(gradient, aspect='auto', cmap='rainbow') 
plt.yticks([])
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()
G.add_edge(1, 2)
G.add_edge(1, 3)
G.add_edge(1, 5)
G.add_edge(2, 3)
G.add_edge(3, 4)
G.add_edge(4, 5)

# explicitly set positions
pos = {1: (0, 0), 2: (-1, 0.3), 3: (2, 0.17), 4: (4, 0.255), 5: (5, 0.03)}

options = {
    "font_size": 36,
    "node_size": 3000,
    "node_color": "green",
    "edgecolors": "black",
    "linewidths": 5,
    "width": 5,
}
nx.draw_networkx(G, pos, **options)

# Set margins for the axes so that nodes aren't clipped
ax = plt.gca()
ax.margins(0.20)
plt.axis("off")
plt.show()

# %%
G = nx.DiGraph([(0, 3), (1, 3), (2, 4), (3, 5), (3, 6), (4, 6), (5, 6)])

# group nodes by column
left_nodes = [0, 1, 2]
middle_nodes = [3, 4]
right_nodes = [5, 6]

# set the position according to column (x-coord)
pos = {n: (0, i) for i, n in enumerate(left_nodes)}
pos.update({n: (1, i + 0.5) for i, n in enumerate(middle_nodes)})
pos.update({n: (2, i + 0.5) for i, n in enumerate(right_nodes)})

nx.draw_networkx(G, pos, **options)

# Set margins for the axes so that nodes aren't clipped
ax = plt.gca()
ax.margins(0.20)
plt.axis("off")
plt.show()
